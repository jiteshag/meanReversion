# %%
import numpy as np
import pandas as pd

stocklist = pd.read_table('stocklist.txt', names=('A'))

df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

for stockname in stocklist['A'] :
    df_all = pd.read_csv("stock_data/"+stockname+".csv")
    df_train=df_all[:60000]
    df_train_resampled_5min = df_train[df_train.index%5==0]
    df_train_resampled_5min = df_train_resampled_5min.reset_index(drop=True)   
    df_train_resampled_5min_svwap = df_train_resampled_5min.iloc[:,1]
    df_train_resampled_5min_svwap = df_train_resampled_5min_svwap.to_frame()
    df_train_resampled_5min_svwap = df_train_resampled_5min_svwap.rename(columns={str(list(df_train_resampled_5min_svwap)):0})

    df_new = pd.DataFrame()
#     spread = Top Ask Price - Top Bid Price
    spread = df_train_resampled_5min.iloc[:,4] - df_train_resampled_5min.iloc[:,3]
    avg_spread = np.mean(spread)
#df_new = pd.DataFrame(data,columns=['Deviations'])
    data = np.array([])
    for i in range(224):
        data= np.append(data, df_train_resampled_5min_svwap.iloc[i,0] ) 
    for i in range(224, 12000):
        data= np.append(data, np.mean(df_train_resampled_5min_svwap.iloc[i-224:i+1])) 
    
        df_new = pd.DataFrame(data)
        
    df_deviations = df_train_resampled_5min_svwap.iloc[:,0]-df_new.iloc[:,0] - spread - 0.2
    df_deviations_positive = df_deviations[df_deviations>0]
   # df_deviations_positive.dropna(axis = 0)
    dev_mean = np.mean(df_deviations_positive)
    no_of_trades = df_deviations_positive.size
    
    s=pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df=df.append(s,ignore_index=True)

    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))
df.to_csv("profits_1d.csv")
# Out:
# JPASSOCIAT:0.7716202581091175:3289
# GMRINFRA:0.47463910466992115:1962
# ASHOKLEY:1.4841570536947946:4685
# SUZLON:0.3467347231421724:1848
# IBREALEST:4.570731799996234:6207
# RELCAPITAL:11.46599371514712:6986
# ADANIENT:2.899491509882729:5635
# DLF:3.179386410556422:6205
# IDFC:0.7335677755557938:3467
# SOUTHBANK:0.315540906784772:2398
# VEDL:4.492795633777357:6212
# SAIL:0.8252110359879824:4354
# IDFCBANK:0.8803160417184567:2535
# FEDERALBNK:1.5685196626356164:5292
# BANKBARODA:2.425958073451448:4952
# MANAPPURAM:1.9204728604551569:5082
# HINDALCO:3.0888513260186037:6366
# TATASTEEL:7.704404249018411:6435
# SBIN:2.7520030020191557:5923
# JINDALSTEL:2.922948680449092:5829
# RCOM:0.5872656810750557:3019
# HDIL:1.4288811348157922:5053
# L_TFH:2.3738449022787678:6430
# TATAMOTORS:5.049362690250614:5358
# NMDC:1.665152797767438:4588
# ADANIPOWER:0.7158682222998052:3390
# HCC:0.6852563121378118:3047
# INDIACEM:3.4961106161202693:5866
# ICICIBANK:3.346232737133466:5804
# SUNTV:14.128021607371435:6012
# RELINFRA:6.37386652655188:6675
# PNB:2.461237354923462:5488
# JSWSTEEL:3.252199303849096:6015
# APOLLOTYRE:3.5009292454456142:5899
# MOTHERSUMI:4.335907214673253:6297
# TATAGLOBAL:2.694742794570229:5046
# RECLTD:3.11792906504976:5776
# ONGC:1.5349097012808712:3743
# RPOWER:0.4227384651416921:2908
# IDEA:2.3840637725074076:4241
# JSWENERGY:1.0809802911291528:4212
# IFCI:0.4277826798919:1960
# DHFL:6.0825105664678425:7773
# TV18BRDCST:0.6170363391703046:3067
# CANBK:5.054325224743474:6013
# BANKINDIA:2.593578270184955:5691
# ORIENTBANK:2.2737566389446466:5552
# PFC:1.965652778536409:5411
# EXIDEIND:2.777405230079121:5027
# NCC:1.289504523714951:4171
# KTKBANK:2.2978168899973554:5370
# BHARATFIN:15.637356304731345:6393
# M_MFIN:6.752997347668358:6008
# GRASIM:14.626807314298834:6786
# NATIONALUM:1.3507544181112239:4014
# AXISBANK:5.930932963121371:5649
# UNIONBANK:2.676400681768394:5534
# AUROPHARMA:10.086792219140973:5776
# INFIBEAM:23.040131674996868:5735
# BEL:7.7592490530071965:5629
# ESCORTS:10.420014885980814:7072
# FORTIS:3.325291395683197:4608
# ALBK:1.1263683106601245:4479
# HINDPETRO:7.710834973835355:6447
# MRPL:2.2704127183360736:5166
# IDBI:0.9060334196008686:3519
# TATAPOWER:0.8294617240742774:3360
# PTC:1.540683481559755:5626
# NHPC:0.39023244409167157:1952
# NTPC:1.385959412898849:4650
# SUNPHARMA:7.084066381460302:5237
# IOC:5.7626752174795906:5876
# BPCL:9.34511153047912:5855
# INFY:9.325301466572176:5453
# RELIANCE:21.196717147086993:5971
# DISHTV:1.2407199984820372:4395
# JUSTDIAL:10.402673759045452:5035
# ITC:3.4357582740426404:5494
# BHEL:1.9716895742587375:4975
# SYNDIBANK:1.1559343357037777:4148
# TATAMTRDVR:2.983171688179574:4800
# HINDZINC:4.09155350678471:5802
# CESC:11.666562038186044:6679
# GAIL:4.982884301231909:5905
# JISLJALEQS:1.5344474967413293:4795
# COALINDIA:2.8385640900992724:4037
# PCJEWELLER:9.164693947276346:5650
# ANDHRABANK:0.8465554115347512:3582
# CGPOWER:3.711898190866338:3278
# POWERGRID:1.7528039679606735:5534
# GSFC:2.518077657688367:5424
# AMBUJACEM:2.8286819961281444:5775
# ADANIPORTS:4.662262834929127:6569
# SREINFRA:2.201590941882344:5535
# EQUITAS:2.715278470685771:4826
# IRB:3.1657918455596135:5331
# DCBBANK:2.685016845792214:6008
# YESBANK:20.961423330246493:6812
# LICHSGFIN:7.035906440907383:6386
# VOLTAS:6.4592434186898195:6406
# TVSMOTOR:6.000960990246585:6652
# RDEL:1.0062811325347105:3744
# KOTAKBANK:7.475447467012163:7001
# SRTRANSFIN:14.213699216976098:5619
# UJJIVAN:7.398015524317951:4980
# WIPRO:3.4782765028822236:6329
# PETRONET:4.68205907134157:5520
# BALRAMCHIN:2.4051626674488213:5270
# BHARTIARTL:4.639123357837036:5909
# HDFCBANK:11.37753651838769:7403
