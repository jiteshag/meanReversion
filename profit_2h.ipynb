# %%
import numpy as np
import pandas as pd

stocklist = pd.read_table('stocklist.txt', names=('A'))

df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

for stockname in stocklist['A'] :
    df_all = pd.read_csv("stock_data/"+stockname+".csv")
    df_train=df_all[:60000]
    df_train_resampled_svwap = df_train.iloc[:,1]
    df_train_resampled_svwap = df_train_resampled_svwap.to_frame()
    df_train_resampled_svwap = df_train_resampled_svwap.rename(columns={str(list(df_train_resampled_svwap)):0})

    df_new = pd.DataFrame()
#     spread = Top Ask Price - Top Bid Price
    spread = df_train.iloc[:,4] - df_train.iloc[:,3]
    avg_spread = np.mean(spread)
#df_new = pd.DataFrame(data,columns=['Deviations'])
    data = np.array([])
    for i in range(359):
        data= np.append(data, df_train_resampled_svwap.iloc[i,0] ) 
    for i in range(359, 60000):
        data= np.append(data, np.mean(df_train_resampled_svwap.iloc[i-359:i+1])) 
    
        df_new = pd.DataFrame(data)
        
    df_deviations = df_train_resampled_svwap.iloc[:,0]-df_new.iloc[:,0] - spread - 0.2
    df_deviations_positive = df_deviations[df_deviations>0]
   # df_deviations_positive.dropna(axis = 0)
    dev_mean = np.mean(df_deviations_positive)
    no_of_trades = df_deviations_positive.size
    
    s=pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df=df.append(s,ignore_index=True)
    
#     data_15d = df_train_resampled_10min_svwap.rolling(window=563).mean()
#     data_5d = df_train_resampled_10min_svwap.rolling(window=188).mean()
#     std = df_train_resampled_10min_svwap.rolling(window=563).std()
    
#     # Start with no money and no positions
#     money = 0
#     count = 0
#     for i in range(6000):
#         if i<562 :
#             count += 0
#         # Sell short if the z-score is > 1
#         elif data_5d[i] > data_15d[i] + std[i]:
#             money += df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]
#         # Buy long if the z-score is < 1
#         elif data_5d[i] < data_15d[i] - std[i]:
#             money -= df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]

    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))
df.to_csv("profits_2h.csv")
# Out:
# JPASSOCIAT:0.5055200096192887:9275
# GMRINFRA:0.32788788749061537:4287
# ASHOKLEY:0.79597699824334:16209
# SUZLON:0.28195511163909237:2849
# IBREALEST:2.742135114192606:24318
# RELCAPITAL:6.170174734397551:30134
# ADANIENT:1.6488365578739377:20638
# DLF:1.8325519190410346:24966
# IDFC:0.45067796058165693:10399
# SOUTHBANK:0.2181304389096214:3313
# VEDL:2.3399802026977645:26870
# SAIL:0.5054106104159698:12450
# IDFCBANK:0.5537696730848174:7064
# FEDERALBNK:0.82904405087184:18494
# BANKBARODA:1.3370434636987367:20696
# MANAPPURAM:1.131270586085004:18610
# HINDALCO:1.7352779072906208:25782
# TATASTEEL:4.132614101161511:27433
# SBIN:1.495092678730497:24619
# JINDALSTEL:1.583248328588145:23209
# RCOM:0.5379260467228263:6105
# HDIL:0.9605662511504168:17168
# L_TFH:1.262478969762439:23347
# TATAMOTORS:2.716762681183996:26282
# NMDC:1.0251756263206235:17321
# ADANIPOWER:0.3565153566742616:9927
# HCC:0.506807085065578:8543
# INDIACEM:1.9890510861865016:23714
# ICICIBANK:2.042641257918479:23165
# SUNTV:7.197237168304596:28432
# RELINFRA:3.9794865260832273:28576
# PNB:1.2811061647191022:22955
# JSWSTEEL:1.8069283484454628:26324
# APOLLOTYRE:2.003963310579344:23819
# MOTHERSUMI:2.6446899592840962:26252
# TATAGLOBAL:1.5424132435086462:18666
# RECLTD:1.7114793646876407:23599
# ONGC:0.9457117434423252:16934
# RPOWER:0.28059972226855423:5857
# IDEA:1.3914409602032043:15414
# JSWENERGY:0.7037447303270593:13959
# IFCI:0.35440434090420736:3568
# DHFL:3.160887329818047:31030
# TV18BRDCST:0.4088991554303915:7565
# CANBK:2.7832757893653404:25139
# BANKINDIA:1.521802490883102:21963
# ORIENTBANK:1.3861199362810195:22293
# PFC:1.2077760316654824:21127
# EXIDEIND:1.526941313907267:21508
# NCC:0.7431743933605526:16269
# KTKBANK:1.2479341285089849:20562
# BHARATFIN:8.801450560474244:27716
# M_MFIN:3.5391219918692767:25912
# GRASIM:7.9958537791427355:29133
# NATIONALUM:0.7041755052368764:15026
# AXISBANK:3.2394965577482755:27071
# UNIONBANK:1.49638982343342:22612
# AUROPHARMA:5.9875263100804705:25270
# INFIBEAM:12.82369488809673:24101
# BEL:4.542206757001435:24663
# ESCORTS:5.445932659661276:28729
# FORTIS:1.8836682389874808:21681
# ALBK:0.6400323475261464:14633
# HINDPETRO:4.305802395593492:28754
# MRPL:1.3563635024762797:20418
# IDBI:0.5518069205806122:10783
# TATAPOWER:0.4532490409444785:10538
# PTC:0.9236351046227963:17253
# NHPC:0.29091293404260854:3308
# NTPC:0.9680542503814051:17531
# SUNPHARMA:3.8376862205917766:24380
# IOC:3.2287694905313877:26085
# BPCL:4.788299906841243:28476
# INFY:5.677317973424459:25820
# RELIANCE:9.45010350515225:28015
# DISHTV:0.7327780178943267:16059
# JUSTDIAL:5.027747923923268:25070
# ITC:1.8039476916827806:24594
# BHEL:1.0298931192868421:20136
# SYNDIBANK:0.6593728496635365:13208
# TATAMTRDVR:1.7984487304165357:21851
# HINDZINC:2.0895908951586017:25285
# CESC:6.1357353480012895:28448
# GAIL:2.9555114856541516:25183
# JISLJALEQS:0.9687816284530109:17118
# COALINDIA:1.6416250205084182:20323
# PCJEWELLER:5.233272529406202:23000
# ANDHRABANK:0.5242448667575814:9656
# CGPOWER:2.1735928406796017:9768
# POWERGRID:1.1791430855510836:20353
# GSFC:1.4224939698461228:19882
# AMBUJACEM:1.635437183262755:23941
# ADANIPORTS:2.5930255601749703:27469
# SREINFRA:1.2643605446054749:20330
# EQUITAS:1.4940024002386703:19125
# IRB:1.810845754400597:23014
# DCBBANK:1.5728365808978506:23150
# YESBANK:10.667800579660462:30541
# LICHSGFIN:3.6443360997118326:27784
# VOLTAS:3.4022119198033796:26616
# TVSMOTOR:3.5372478144378436:25702
# RDEL:0.6831463016267916:10908
# KOTAKBANK:4.451972461968775:28599
# SRTRANSFIN:7.916769992823619:26370
# UJJIVAN:3.9325294977799037:22408
# WIPRO:2.083303509194169:25031
# PETRONET:2.664445031607389:25359
# BALRAMCHIN:1.3422227419606636:21109
# BHARTIARTL:2.9176796481698073:23720
# HDFCBANK:6.0070323962495875:30123
