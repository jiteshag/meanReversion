# %%
import numpy as np
import pandas as pd

stocklist = pd.read_table('stocklist.txt', names=('A'))

df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

for stockname in stocklist['A'] :
    df_all = pd.read_csv("stock_data/"+stockname+".csv")
    df_train=df_all[:60000]
    df_train_resampled_svwap = df_train.iloc[:,1]
    df_train_resampled_svwap = df_train_resampled_svwap.to_frame()
    df_train_resampled_svwap = df_train_resampled_svwap.rename(columns={str(list(df_train_resampled_svwap)):0})

    df_new = pd.DataFrame()
#     spread = Top Ask Price - Top Bid Price
    spread = df_train.iloc[:,4] - df_train.iloc[:,3]
    avg_spread = np.mean(spread)
#df_new = pd.DataFrame(data,columns=['Deviations'])
    data = np.array([])
    for i in range(119):
        data= np.append(data, df_train_resampled_svwap.iloc[i,0] ) 
    for i in range(119, 6000):
        data= np.append(data, np.mean(df_train_resampled_svwap.iloc[i-119:i+1])) 
    
        df_new = pd.DataFrame(data)
        
    df_deviations = df_train_resampled_svwap.iloc[:,0]-df_new.iloc[:,0] - spread - 0.2
    df_deviations_positive = df_deviations[df_deviations>0]
   # df_deviations_positive.dropna(axis = 0)
    dev_mean = np.mean(df_deviations_positive)
    no_of_trades = df_deviations_positive.size
    
    s=pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df=df.append(s,ignore_index=True)
    
#     data_15d = df_train_resampled_10min_svwap.rolling(window=563).mean()
#     data_5d = df_train_resampled_10min_svwap.rolling(window=188).mean()
#     std = df_train_resampled_10min_svwap.rolling(window=563).std()
    
#     # Start with no money and no positions
#     money = 0
#     count = 0
#     for i in range(6000):
#         if i<562 :
#             count += 0
#         # Sell short if the z-score is > 1
#         elif data_5d[i] > data_15d[i] + std[i]:
#             money += df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]
#         # Buy long if the z-score is < 1
#         elif data_5d[i] < data_15d[i] - std[i]:
#             money -= df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]

    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))
df.to_csv("profits_2h.csv")
# Out:
# JPASSOCIAT:0.7079239703754733:320
# GMRINFRA:nan:0
# ASHOKLEY:0.30111286219611094:715
# SUZLON:0.20947973531441705:137
# IBREALEST:0.4016166313834196:1199
# RELCAPITAL:1.6193824440250428:2082
# ADANIENT:0.3246503405639476:575
# DLF:0.7882224428199008:1376
# IDFC:0.1757944907129065:449
# SOUTHBANK:nan:0
# VEDL:1.0238833756918564:2225
# SAIL:0.37152028335471743:841
# IDFCBANK:0.1476421063651612:177
# FEDERALBNK:0.23975251855704277:1152
# BANKBARODA:0.6760155740190704:1153
# MANAPPURAM:0.5300808186703572:1109
# HINDALCO:1.0191200179925106:1984
# TATASTEEL:2.246641634141257:2496
# SBIN:0.6070698331221224:1670
# JINDALSTEL:0.680098865806459:1231
# RCOM:0.17464220758172644:97
# HDIL:0.3371254319195673:437
# L_TFH:0.3420632396609242:780
# TATAMOTORS:2.5477801273614524:2361
# NMDC:0.7005918733866762:1725
# ADANIPOWER:0.20945761779842223:443
