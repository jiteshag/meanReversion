# %%
import numpy as np
import pandas as pd

stocklist = pd.read_table('stocklist.txt', names=('A'))

df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

for stockname in stocklist['A'] :
    df_all = pd.read_csv("stock_data/"+stockname+".csv")
    df_train=df_all[:60000]
    df_train_resampled_10min = df_train[df_train.index%10==0]
    df_train_resampled_10min = df_train_resampled_10min.reset_index(drop=True)   
    df_train_resampled_10min_svwap = df_train_resampled_10min.iloc[:,1]
    df_train_resampled_10min_svwap = df_train_resampled_10min_svwap.to_frame()
    df_train_resampled_10min_svwap = df_train_resampled_10min_svwap.rename(columns={str(list(df_train_resampled_10min_svwap)):0})

    df_new = pd.DataFrame()
#     spread = Top Ask Price - Top Bid Price
    spread = df_train_resampled_10min.iloc[:,4] - df_train_resampled_10min.iloc[:,3]
    avg_spread = np.mean(spread)
#df_new = pd.DataFrame(data,columns=['Deviations'])
    data = np.array([])
    for i in range(187):
        data= np.append(data, df_train_resampled_10min_svwap.iloc[i,0] ) 
    for i in range(187, 6000):
        data= np.append(data, np.mean(df_train_resampled_10min_svwap.iloc[i-187:i+1])) 
    
        df_new = pd.DataFrame(data)
        
    df_deviations = df_train_resampled_10min_svwap.iloc[:,0]-df_new.iloc[:,0] - spread - 0.2
    df_deviations_positive = df_deviations[df_deviations>0]
   # df_deviations_positive.dropna(axis = 0)
    dev_mean = np.mean(df_deviations_positive)
    no_of_trades = df_deviations_positive.size
    
    s=pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df=df.append(s,ignore_index=True)
    
#     data_15d = df_train_resampled_10min_svwap.rolling(window=563).mean()
#     data_5d = df_train_resampled_10min_svwap.rolling(window=188).mean()
#     std = df_train_resampled_10min_svwap.rolling(window=563).std()
    
#     # Start with no money and no positions
#     money = 0
#     count = 0
#     for i in range(6000):
#         if i<562 :
#             count += 0
#         # Sell short if the z-score is > 1
#         elif data_5d[i] > data_15d[i] + std[i]:
#             money += df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]
#         # Buy long if the z-score is < 1
#         elif data_5d[i] < data_15d[i] - std[i]:
#             money -= df_train_resampled_10min.iloc[i,1]*df_train_resampled_10min.iloc[i,5]
#             count += df_train_resampled_10min.iloc[i,5]

    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))
df.to_csv("profits_5d.csv")
# Out:
# JPASSOCIAT:0.9515472215924907:1912
# GMRINFRA:0.5742717604139106:1249
# ASHOKLEY:1.9587633388634529:2576
# SUZLON:0.41034200696313905:1066
# IBREALEST:6.116402199155131:3282
# RELCAPITAL:14.659571667629427:3762
# ADANIENT:3.816020293602128:3166
# DLF:4.009017291856191:3377
# IDFC:0.8721558182528636:1954
# SOUTHBANK:0.3898546881253819:1740
# VEDL:5.620999520826774:3376
# SAIL:1.1087465634813543:2412
# IDFCBANK:1.1472222660837503:1533
# FEDERALBNK:1.9936380496952402:3059
# BANKBARODA:3.130577205352862:2566
# MANAPPURAM:2.4745735343686945:2697
# HINDALCO:4.274287314039771:3201
# TATASTEEL:9.92960261759429:3498
# SBIN:3.8484992464489522:3012
# JINDALSTEL:3.709973123693916:3196
# RCOM:0.777692119719674:1812
# HDIL:1.7778131176099499:2752
# L_TFH:3.1080811847490835:3657
# TATAMOTORS:6.319892783942549:2636
# NMDC:2.1726800343563983:2372
# ADANIPOWER:0.9117257723443162:1973
# HCC:0.8090546071147888:1631
# INDIACEM:4.723043018948118:3072
# ICICIBANK:4.3631008420450215:3103
# SUNTV:19.98779657898062:3039
# RELINFRA:7.546549779486676:3564
# PNB:3.565316351516233:2689
# JSWSTEEL:4.445375571347109:3099
# APOLLOTYRE:4.477923018684419:3217
# MOTHERSUMI:5.296458061951048:3463
# TATAGLOBAL:3.6431159901415473:2766
# RECLTD:4.274712384525912:2852
# ONGC:1.748876585807774:1651
# RPOWER:0.5052881485084733:1823
# IDEA:3.296887351923355:2175
# JSWENERGY:1.37159359995492:2123
# IFCI:0.590292212720573:1254
# DHFL:8.508583407495516:4130
# TV18BRDCST:0.7919152798649766:1768
# CANBK:6.801375650086531:3106
# BANKINDIA:3.385162563492131:3095
# ORIENTBANK:2.9638703519875937:2952
# PFC:2.50420912590686:2814
# EXIDEIND:3.3183148639106936:2761
# NCC:1.597682390696562:2254
# KTKBANK:3.110225952064153:2855
# BHARATFIN:20.340185694610906:3264
# M_MFIN:9.037615038727782:3088
# GRASIM:20.311463527077006:3584
# NATIONALUM:1.6696765286944346:2181
# AXISBANK:7.263445759315529:2930
# UNIONBANK:3.5653825448447085:2848
# AUROPHARMA:13.654595688389156:2897
# INFIBEAM:30.31822904813226:3075
# BEL:10.104272035820946:2873
# ESCORTS:14.56903540569736:3718
# FORTIS:4.209194131743701:2305
# ALBK:1.3883606811293832:2689
# HINDPETRO:10.195315964873847:3257
# MRPL:2.8434859075798866:2773
# IDBI:1.1404128457450573:1906
# TATAPOWER:1.001841648728229:1938
# PTC:2.05486945629326:2974
# NHPC:0.517286054046566:1255
# NTPC:1.9190010970837303:2354
# SUNPHARMA:9.047565461446618:2601
# IOC:7.855036632352521:2840
# BPCL:12.483923893931827:2903
# INFY:10.888792091861312:2918
# RELIANCE:29.015242227478677:3119
# DISHTV:1.7567077272411138:2230
# JUSTDIAL:14.0474638903123:2452
# ITC:4.6125014185444355:2923
# BHEL:2.491465664448456:2654
# SYNDIBANK:1.4962777412057786:2362
# TATAMTRDVR:3.519293273393072:2327
# HINDZINC:5.23027837732785:3106
# CESC:16.276923491674488:3600
# GAIL:6.753476632689564:2913
# JISLJALEQS:1.9827092002974849:2598
# COALINDIA:3.734220329121082:1749
# PCJEWELLER:12.03003237170365:2906
# ANDHRABANK:1.0745597400167624:2224
# CGPOWER:5.026319358499974:1941
# POWERGRID:2.3123692342513738:2853
# GSFC:3.370273741904074:2919
# AMBUJACEM:3.7835866704272023:3194
# ADANIPORTS:5.8995208431881805:3405
# SREINFRA:2.9244746492072173:2924
# EQUITAS:3.320873587447733:2708
# IRB:4.0464467766020356:2685
# DCBBANK:3.4819698939176966:3225
# YESBANK:27.571193285284853:3641
# LICHSGFIN:9.793668862077485:3382
# VOLTAS:8.267804016521259:3527
# TVSMOTOR:7.503798869876022:3725
# RDEL:1.239215190866668:2085
# KOTAKBANK:10.008482610001755:3650
# SRTRANSFIN:17.231248204459696:2919
# UJJIVAN:9.96854877440828:2533
# WIPRO:4.404813988986408:3514
# PETRONET:5.706413604011641:2918
# BALRAMCHIN:2.997524919365719:2768
# BHARTIARTL:5.748669546531168:3187
# HDFCBANK:15.518280596025582:4096
